# %%
from pyspark.sql.functions import *

# %% [markdown]
# ## Customer Data

# %%
# Ingesting Data From Volumes
raw_customers_df = spark.read.format("csv")\
        .option("header", "true")\
        .option("InferSchema", "true")\
        .load("/Volumes/projects/project_1/landing/olist_customers_dataset.csv")

# %%
#writing the customers data into a delta table
bronze_customers_df = raw_customers_df.withColumn("ingested_at", current_timestamp())
bronze_customers_df.write.format("delta")\
    .mode("overwrite")\
    .saveAsTable("projects.project_1.bronze_customers")

# %% [markdown]
# ## ORDERS DATA

# %%
orders_raw_df = spark.read.format("csv")\
        .option("header", "true")\
        .option("InferSchema", "true")\
        .load("/Volumes/projects/project_1/landing/olist_orders_dataset.csv")

# %%
bronze_orders_df = orders_raw_df.withColumn("ingested_at", current_timestamp())
bronze_orders_df.write.format("delta")\
    .mode("overwrite")\
    .saveAsTable("projects.project_1.bronze_orders")

# %% [markdown]
# ## Products Data

# %%
products_raw_df = spark.read.format("csv")\
                    .option("header", "true")\
                    .option("inferSchema", "true")\
                    .load("/Volumes/projects/project_1/landing/olist_products_dataset.csv")

# %%
products_bronze_df = products_raw_df.withColumn("ingested_at", current_timestamp())
products_bronze_df.write.format("delta")\
    .mode("overwrite")\
    .saveAsTable("projects.project_1.bronze_products")

# %% [markdown]
# ## Sellers Data

# %%
sellers_raw_df = spark.read.format("csv")\
                    .option("header", "true")\
                    .option("inferSchema", "true")\
                    .load("/Volumes/projects/project_1/landing/olist_sellers_dataset.csv")

# %%
sellers_bronze_df = sellers_raw_df.withColumn("ingested_at", current_timestamp())
sellers_bronze_df.write.format("delta")\
    .mode("overwrite")\
    .saveAsTable("projects.project_1.bronze_sellers")

# %% [markdown]
# ## Products Category

# %%
products_category_df = spark.read.format("csv")\
        .option("header", "true")\
        .option("inferSchema", "true")\
        .load("/Volumes/projects/project_1/landing/product_category_name_translation.csv")

# %%
products_cat_bronze_df = products_category_df.withColumn("ingested_at", current_timestamp())

products_cat_bronze_df.write.format("delta")\
            .mode("overwrite")\
            .saveAsTable("projects.project_1.bronze_products_category")

# %% [markdown]
# ## Order_Items

# %%
order_item_df = spark.read.format("csv")\
        .option("header","true")\
        .option("inferSchema","true")\
        .load("/Volumes/projects/project_1/landing/olist_order_items_dataset.csv")

# %%
order_items_bronze_df = order_item_df.withColumn("ingested_at", current_timestamp())
order_items_bronze_df.write.format("delta")\
        .mode("overwrite")\
        .saveAsTable("projects.project_1.bronze_order_items")

# %% [markdown]
# ## Order Payments

# %%
order_payments_df = spark.read.format("csv")\
        .option("header","true")\
        .option("inferSchema","true")\
        .load("/Volumes/projects/project_1/landing/olist_order_payments_dataset.csv")

# %%
order_payments_bronze_df = order_payments_df.withColumn("ingested_at", current_timestamp())
order_payments_bronze_df.write.format("delta")\
        .mode("overwrite")\
        .saveAsTable("projects.project_1.bronze_order_payments")

# %% [markdown]
# ## Order Reviews

# %%
order_reviews_df = spark.read.format("csv")\
        .option("header","true")\
        .option("inferSchema","true")\
        .load("/Volumes/projects/project_1/landing/olist_order_reviews_dataset.csv")
order_reviews_bronze_df = order_reviews_df.withColumn("ingested_at", current_timestamp())
order_reviews_bronze_df.write.format("delta")\
        .mode("overwrite")\
        .saveAsTable("projects.project_1.order_reviews_bronze")

# %% [markdown]
# ## Geo Location

# %%
geo_location_df = spark.read.format("csv")\
        .option("header","true")\
        .option("inferSchema","true")\
        .load("/Volumes/projects/project_1/landing/olist_geolocation_dataset.csv")
geo_location_bronze_df = geo_location_df.withColumn("ingested_at", current_timestamp())
geo_location_bronze_df.write.format("delta")\
        .mode("overwrite")\
        .saveAsTable("projects.project_1.geo_location_bronze")
